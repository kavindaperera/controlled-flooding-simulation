# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import matplotlib.patches as mpatches

# %%
x = [40, 50, 60, 70, 80, 90, 100]
y_spd_60_1 = [
        (266+155)/(300+266)*100,
        (237+139)/(300+237)*100,
        (299+240)/(300+299)*100,
        (241+178)/(300+241)*100,
        (232+142)/(300+232)*100,
        (292+206)/(300+292)*100,
        (299+226)/(300+299)*100,
    ]

y_dd = [
        (299+231)/(300+299)*100,
        (296+249)/(300+296)*100,
        (299+255)/(300+299)*100,
        (297+252)/(300+297)*100,
        (299+234)/(300+299)*100,
        (299+217)/(300+299)*100,
        (299+238)/(300+299)*100,
    ]

y_spd_30_1 = [
        (278+163)/(300+278)*100,
        (200+118)/(300+200)*100,
        (280+219)/(300+280)*100,
        (263+163)/(300+263)*100,
        (257+164)/(300+257)*100,
        (297+190)/(300+297)*100,
    
        (300+300)/(300+300)*100,
    ]

y_spd_30_2 = [
        (289+216)/(300+289)*100,
        (249+179)/(300+249)*100,
        (299+213)/(300+299)*100,
        (271+217)/(300+271)*100,
        (293+203)/(300+293)*100,
    
        (300+300)/(300+300)*100,
        (300+300)/(300+300)*100,
    ]


plt.xlabel("No of Nodes")
plt.ylabel("PDF%")
plt.yticks(np.arange(0, 102, 2))
plt.grid()

plt.plot(x, y_spd_60_1, 'g-x') 
plt.plot(x, y_dd, 'r-x') 
plt.plot(x, y_spd_30_1, 'b-x') 
plt.plot(x, y_spd_30_2, 'y-x') 

red_patch = mpatches.Patch(color='red', label='DD')
green_patch = mpatches.Patch(color='green', label='SPD-60-1')
blue_patch = mpatches.Patch(color='blue', label='SPD-30-1')
ylw_patch = mpatches.Patch(color='yellow', label='SPD-30-2')
time = mpatches.Patch(color='white', label='sim-time = 300sec')
rate = mpatches.Patch(color='white', label='1 pkt/sec')

plt.legend(handles=[red_patch, green_patch, blue_patch,ylw_patch, time, rate])

fig = plt.gcf()
fig.set_size_inches(8, 8)

# %%
df_1 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data_2\\static_spd_60_1.csv')
df_2 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data_2\\static_dd.csv')
df_4 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data_2\\static_spd_30_2.csv')

# %%
df_1.Module = df_1.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_2.Module = df_2.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_4.Module = df_4.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
x = ['DD', 'SPD-60-1','SPD-30-2']
y = [df_2.nbDataPacketsForwarded.mean(), 
     df_1.nbDataPacketsForwarded.mean(), 
     df_4.nbDataPacketsForwarded.mean()]

# %%
sns.barplot(x, y)
plt.xlabel("Flooding Mode")
plt.ylabel("Avg. No of Pkts Forwarded")
plt.title("Static Mobility")
plt.show()
