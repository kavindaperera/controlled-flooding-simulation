# %% [markdown]
# # Static Mobility

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df_1 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data-static\\data_1.csv')
df_2 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data-static\\data_2.csv')
df_3 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data-static\\data_3.csv')

# %%
df_1.Module = df_1.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_2.Module = df_2.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_3.Module = df_3.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
# plt.plot(df_2.Module, df_2.nbDataPacketsForwarded,  'r-x') # lhc and dd rule
# plt.plot(df_3.Module, df_3.nbDataPacketsForwarded,  'y-x') # spd rule
# fig = plt.gcf()
# fig.set_size_inches(20, 5)

# %%
x = ['TARP-DD', 'TARP-SPD']
y = [df_2.nbDataPacketsForwarded.mean(),  df_3.nbDataPacketsForwarded.mean()]

sns.barplot(x, y)
plt.xlabel("Protocol")
plt.ylabel("Avg. No of Pkts Forwarded")
plt.title("Static Mobility") # You can comment this line out if you don't need title
plt.show()

# %% [markdown]
# # Random Waypoint Mobility

# %%
x = [0,50, 100, 200, 250, 300]

y = [(237+164)/(300+237)*100, #0 
     (298+165)/(300+298)*100, #50
     (298+197)/(300+298)*100, #100
     (299+209)/(300+299)*100, #200
     (299+230)/(300+299)*100, #250
     (299+231)/(300+299)*100, #300
    ]

plt.xlabel("Pause Time")
plt.ylabel("PDF%")

plt.yticks(np.arange(0,102, 2))
plt.grid()
plt.plot(x, y,  'b-o') 
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %%
x = [0, 50, 100,  150, 200, 250, 300]

y = [(237)/(300)*100, #0 
     (298)/(300)*100, #50
     (298)/(300)*100, #100
     (298)/(300)*100, #150
     (299)/(300)*100, #200
     (299)/(300)*100, #250
     (299)/(300)*100, #300
    ]

y_2 = [(254)/(300)*100, #0 
     (200)/(300)*100, #50
     (245)/(300)*100, #100
     (245)/(300)*100, #150
     (253)/(300)*100, #200
     (266)/(300)*100, #250
     (266)/(300)*100, #300
    ]

plt.xlabel("Pause Time")
plt.ylabel("PDF%")

plt.yticks(np.arange(0,102, 4))
plt.xticks(np.arange(0,305, 25))
plt.grid()

plt.plot(x, y,  'r-o') 
plt.plot(x, y_2,  'b-X') 

fig = plt.gcf()
fig.set_size_inches(12, 6)
