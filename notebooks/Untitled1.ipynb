# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import matplotlib.patches as mpatches

# %%
x_aodv = [0, 50, 100, 150, 200, 250]
y_aodv = [
        (201+196)/(300+201)*100, # 0
        (221+216)/(300+221)*100, # 50
        (260+234)/(300+260)*100, # 100
        (260+232)/(300+260)*100, # 150
        (276+272)/(300+276)*100, # 200
        (280+276)/(300+280)*100, # 250
    ]

x_tarp_dd = [0, 50, 100, 150, 200]
y_tarp_dd = [
        (299+194)/(300+299)*100, # 0
        (271+177)/(300+271)*100, # 50
        (299+212)/(300+299)*100, # 100
        (299+225)/(300+299)*100, # 150
        (299+244)/(300+299)*100, # 200
    ]

x_tarp_spd = [0, 50, 100, 150, 200]
y_tarp_spd = [
        (299+191)/(300+299)*100, # 0
        (271+160)/(300+271)*100, # 50
        (299+190)/(300+299)*100, # 100
        (297+198)/(300+297)*100, # 150
        (297+217)/(300+297)*100, # 200
    ]

plt.xlabel("Pause Time (sec)")
plt.ylabel("PDF%")
plt.yticks(np.arange(0, 102, 2))
plt.grid()

plt.plot(x_aodv, y_aodv, 'g-x')
plt.plot(x_tarp_dd, y_tarp_dd,  'b-o') 
plt.plot(x_tarp_spd, y_tarp_spd,  'r-X') 

# red_patch = mpatches.Patch(color='red', label='The red data')
tarp_dd = mpatches.Patch(color='blue', label='TARP-DD')
tarp_spd = mpatches.Patch(color='red', label='TARP-SPD')
nodes = mpatches.Patch(color='white', label='Total Nodes = 70')
rate = mpatches.Patch(color='white', label='1 packet/sec')

plt.legend(handles=[ tarp_dd, tarp_spd, nodes, rate])

fig = plt.gcf()
fig.set_size_inches(8, 8)

# %%
df_1 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data_1\\tarp-spd-60.csv')
df_2 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\data_1\\tarp-dd-60.csv')

# %%
df_1.Module = df_1.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_2.Module = df_2.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
x = ['TARP-DD', 'TARP-SPD']
y = [df_2.nbDataPacketsForwarded.mean(), df_1.nbDataPacketsForwarded.mean()]

sns.barplot(x, y)
plt.xlabel("Protocol")
plt.ylabel("Avg. No of Pkts Forwarded")
plt.title("Static Mobility") # You can comment this line out if you don't need title
plt.show()
