# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df_1 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_1.csv')
df_2 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_2.csv')

# %%
df_1.Module = df_1.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
df_2.Module = df_2.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
plt.plot(df_1.Module, df_1.nbDataPacketsForwarded,  'bx')
plt.plot(df_2.Module, df_2.nbDataPacketsForwarded,  'rx')
fig = plt.gcf()
fig.set_size_inches(20, 5)
fig.savefig('test2png.png', dpi=300)

# %%
df_3 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_3.csv')
df_4 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_4.csv')
df_5 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_5.csv')
df_6 = pd.read_csv('C:\\omnetpp-5.6.2\\samples\\tarp-sim\\results\\dataset_6.csv')

# %%
df_3.Module = df_3.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_4.Module = df_4.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_5.Module = df_5.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]
df_6.Module = df_6.Module.str.split('[',expand=True)[1].str.split(']',expand=True)[0]

# %%
df_4.head()
# Out:
#                                                 run  repetition Module  \
# 0  RandomWaypointMobility-0-20210918-08:58:47-14320           0      0
# 1  RandomWaypointMobility-0-20210918-08:58:47-14320           0      1
# 2  RandomWaypointMobility-0-20210918-08:58:47-14320           0      2
# 3  RandomWaypointMobility-0-20210918-08:58:47-14320           0      3
# 4  RandomWaypointMobility-0-20210918-08:58:47-14320           0      4
#
#    nbDataPacketsForwarded
# 0                     466
# 1                     465
# 2                     496
# 3                     484
# 4                     313

# %%
plt.plot(df_3.Module, df_3.nbDataPacketsForwarded,  'b-x') # not spd
plt.plot(df_4.Module, df_4.nbDataPacketsForwarded,  'r-x') # spd
plt.plot(df_5.Module, df_5.nbDataPacketsForwarded,  'g-x') # 50s cache clear time
plt.plot(df_6.Module, df_6.nbDataPacketsForwarded,  'y-x') # 100s pause time
fig = plt.gcf()
fig.set_size_inches(20, 5)
